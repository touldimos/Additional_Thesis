# %%
path = r'C:\Users\owner\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts'
import sys
sys.path.append(path)
from Climate_all import Climate
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual

prec1 = r'C:\Users\owner\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts\wc2.1_10m_prec\wc2.1_10m_prec_0{}.tif'
prec2 = r'C:\Users\owner\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts\wc2.1_10m_prec\wc2.1_10m_prec_{}.tif'
temp1 = r'C:\Users\owner\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts\wc2.1_10m_tavg\wc2.1_10m_tavg_0{}.tif'
temp2 = r'C:\Users\owner\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts\wc2.1_10m_tavg\wc2.1_10m_tavg_{}.tif'
elev_raster = r'C:\Users\owner\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts\wc2.1_10m_elev\wc2.1_10m_elev.tif'
  
# m = np.random.randint(0, cols) #Lenght (Χ) 
# n = np.random.randint(0, rows) #Width  (Υ)

m = 1195      #GREECE
n = 285       #GREECE

l = 4
k = 4


# m = 0           #X
# n = 0           #Y

# l = rows        #Lenght (Χ)
# k = cols        #Width  (Υ)

df, net_time = Climate(path, prec1, prec2, temp1, temp2, elev_raster, m, n, k, l, 0, 60, True)

print('')
print(net_time)
# Out:
# Peaks: [11]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f36e37b33b55> in <module>
#      28 # k = cols        #Width  (Υ)
#      29
# ---> 30 df, net_time = Climate(path, prec1, prec2, temp1, temp2, elev_raster, m, n, k, l, 0, 60, True)
#      31
#      32 print('')
#
# ~\Google Drive 2\MSc\TU DELFT - Water Managment\Additional Thesis\Scripts\Climate_all.py in Climate(path, prec1, prec2, temp1, temp2, elev_raster, m, n, l, k, rot, el, ter)
#     231             return cmp
#     232
# --> 233         plt.imshow(mapping2, cmap=get_continuous_cmap(colors))
#     234         plt.grid()
#     235         plt.xticks([])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2876         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2877         url=url, **({"data": data} if data is not None else {}),
# -> 2878         **kwargs)
#    2879     sci(__ret)
#    2880     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5587                               resample=resample, **kwargs)
#    5588
# -> 5589         im.set_data(X)
#    5590         im.set_alpha(alpha)
#    5591         if im.get_clip_path() is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     699                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     700             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 701                             "float".format(self._A.dtype))
#     702
#     703         if self._A.ndim == 3 and self._A.shape[-1] == 1:
#
# TypeError: Image data of dtype <U1 cannot be converted to float

# %%
def terrain(a, e):
    fig = plt.figure(figsize = (5, 5))
    ax = fig.gca(projection='3d')
    ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
    surf=ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
    fig.colorbar(surf, shrink=0.5, aspect=5)
    ax.view_init(azim = a, elev = e)

interact(terrain, a = (0, 90, 5), e = (0, 90, 5));
# Out:
# interactive(children=(IntSlider(value=45, description='a', max=90, step=5), IntSlider(value=45, description='e…
